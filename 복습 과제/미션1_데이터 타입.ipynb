# %% [markdown]
# ### 점프투 파이썬의 딕셔너리 구조를 공부합니다.
# https://wikidocs.net/16

# %%
a=[1,2,3,4,5]
if isinstance(a,list)==True:
  print('list')
# Out:
# list

# %% [markdown]
# ### [미션1] 딕셔너리 구조의 인덱싱
# - 딕셔너리 구조는 json 파일 형식으로 작성할수 있음.
# - 외부데이터 셋으로 많이 보는 형식임

# %%
data={'여행지':['서울시내','경기','전주','부산','제주'],
  '예상경비1일':['50000','100000','200000'],
  '예상일정': ['3일','2일']
  }
print(type(data))
# Out:
# <class 'dict'>

# %%
data
# Out:
# {'여행지': ['서울시내', '경기', '전주', '부산', '제주'],
#  '예상경비1일': ['50000', '100000', '200000'],
#  '예상일정': ['3일', '2일']}

# %%
data['여행지']
# Out:
# ['서울시내', '경기', '전주', '부산', '제주']

# %%
# 미션: data의 '예상일정'을 출력합니다.
data['예상일정']
# Out:
# ['3일', '2일']

# %%
# 미션: data의 '여행지'의 첫번째 '서울시내'를 출력합니다.
data['여행지'][0]
# Out:
# '서울시내'

# %%
# 미션: data의 '여행지'의  두번째,세번째 '경기','전주'를 출력합니다.
data['여행지'][1:3]
# Out:
# ['경기', '전주']

# %%
# 미션: data의 '여행지'의 끝에서 두번째 '부산'을 출력합니다. (- 값으로 인덱싱) 
data['여행지'][-2]
# Out:
# '부산'

# %% [markdown]
# ### [미션2] 데이터 원소갯수 구하기 (len함수)

# %%
len(data)
# Out:
# 3

# %%
# 미션2-1: 여행지, 예상경비1일, 예상일정의 항목갯수(원소갯수)를 print문으로 출력합니다.

# %%
# 미션2-1: 여행지, 예상경비1일, 예상일정의 항목갯수(원소갯수)를 print문으로 출력합니다.
print(len(data['여행지']), len(data['예상경비1일']), len(data['예상일정']))
# Out:
# 5 3 2

# %%
# 미션2-2 : for를 이용하여서 미션 2-1 구문을 변경합니다. 
itemList=['여행지','예상경비1일','예상일정']

for item in itemList:
    print(len(data[item]))
# Out:
# 5
# 3
# 2

# %%
# 미션2-3 : 미션 2-1의 for구문에 if문을 추가합니다.
# 항목갯수가  3미만(<3)일때는 print문으로 '항목갯수가 작음. 추가바람'
itemList=['여행지','예상경비1일','예상일정']

for item in itemList:
    if len(data[item]) < 3:
        print('항목 개수가 작음. 추가 바람')
    else:
        print(len(data[item]))
# Out:
# 5
# 3
# 항목 개수가 작음. 추가 바람

# %% [markdown]
# ### [미션3] 랜덤값으로 여행일정 짜기

# %%
import random
randomNum=random.randrange(0,4)   # 0,1,2,3의 random값 나옴 ctrl+enter 여러번 수행하면서 확인
randomNum
# Out:
# 3

# %%
## 미션 3-1: 여행지의 갯수가 0,1,2,3,4번 5개임, 0~5개의 숫자가 나올수 있도록 작성합니다.
##  여행지에서 random하게 지역을 출력합니다.

import random
randomNum=random.randrange(0, 5)
print(data['여행지'][randomNum])
# Out:
# 부산

# %%
## 미션 3-2: random으로 나올수 있는 마지막 값을 여행지의 갯수 len함수로 지정함.

random
# Out:
# <module 'random' from 'c:\\Users\\bluecom009\\miniconda3\\envs\\OpenAI\\Lib\\random.py'>

# %%
## 미션 3-3: random으로 여행지, 예상경비1일,예상일정을 출력하세요

# 컴프리헨션을 사용

random_dict = {key: random.choice(values) for key, values in data.items()}
print(random_dict)

# 노가다. 딕셔너리로 출력 안하고 
print(random.choice(data['여행지']), random.choice(data['예상경비1일']), random.choice(data['예상일정']))
# Out:
# {'여행지': '제주', '예상경비1일': '50000', '예상일정': '2일'}
# 제주 200000 3일

# %%
## 미션 3-4: 미션3-3을 for 로 작성하지 않았다면 for로 변경

# for로 딕셔너리에서 key, value 값을 뽑아내기
random_for = {}

for key, value in data.items():
    random_for[key] = random.choice(value)

random_for
# Out:
# {'여행지': '경기', '예상경비1일': '50000', '예상일정': '2일'}

# %%
## 미션 3-5: for로 변경된 구문울 이용하여서  랜덤여행일정 리스트를 제작
# 출력예 ==> 랜덤여행일정=['경기','50000','3일']

랜덤여행일정 = {}

for key, value in data.items():
    랜덤여행일정[key] = random.choice(value)
랜덤여행일정 = list(랜덤여행일정.values())

랜덤여행일정
# Out:
# ['서울시내', '200000', '3일']

# %%
# 미션3-6: 랜덤여행일정의 자료의 1번 인덱스의 '50000'을 숫자형으로 변경
#          랜덤여행일정 자료의 2번 인덱스의 '3일'의 '일'을 제거하고 숫자형으로 변경 (구글검색  '파이썬 replace')
#          최종결과는
# 랜덤여행일지=['경기',50000,3,150000]    #마지막은 1일경비*예상일정

랜덤여행일정[1]=int(랜덤여행일정[1])
랜덤여행일정[2] = int(랜덤여행일정[2].replace('3일', '3'))

랜덤여행일정
# Out:
# ['서울시내', 200000, 3]

# %% [markdown]
# ### [미션4] 정규표현식에 대하여 공부하여 봅니다.
# - 구글검색: 파이썬 re.sub
# - https://wikidocs.net/1642    (점프투파이썬)

# %%
data={'여행지':['서울시내','경기','전주','부산','제주'],
  '예상경비1일':['50000','100000','200000'],
  '예상일정': ['!3일정도','2일^^^']
  }
print(type(data))
# Out:
# <class 'dict'>

# %%
# [미션] 위와같은 구문에서 data['예상일정']에서 숫자만 남기고 나머지 글자는 모두 제거

import re

# data['예상일정'] = re.sub(data['예상일정'], )

if '예상일정' in data:
    data['예상일정'] = [re.sub(r'\D', '', value) for value in data['예상일정']]
print(data)
# Out:
# {'여행지': ['서울시내', '경기', '전주', '부산', '제주'], '예상경비1일': ['50000', '100000', '200000'], '예상일정': ['3', '2']}

# %% [markdown]
# ### [미션5]:
# - 아래와 같은 여행 일정의, 국내여행과 해외여행에 관한 정보가 있는 딕셔너리 구조에서의 인덱싱

# %%
data={'여행': [
{'여행지':['서울시내','경기','전주','부산','제주'],
  '예상경비1일':['50000','100000','200000'],
  '예상일정': ['!3일정도','2일^^^']
  }
,
{'여행지':['유럽','아시아'],
  '예상경비1일':['100000','400000','300000','150000'],
  '예상일정': ['4일갈까?','~7일도좋아','20일##']
  }]
}
data
# Out:
# {'여행': [{'여행지': ['서울시내', '경기', '전주', '부산', '제주'],
#    '예상경비1일': ['50000', '100000', '200000'],
#    '예상일정': ['!3일정도', '2일^^^']},
#   {'여행지': ['유럽', '아시아'],
#    '예상경비1일': ['100000', '400000', '300000', '150000'],
#    '예상일정': ['4일갈까?', '~7일도좋아', '20일##']}]}

# %%
# 미션 : 국내여행만 출력

data['여행'][0]
# Out:
# {'여행지': ['서울시내', '경기', '전주', '부산', '제주'],
#  '예상경비1일': ['50000', '100000', '200000'],
#  '예상일정': ['!3일정도', '2일^^^']}

# %%
# 미션: 해외여행만 출력

data['여행'][1]
# Out:
# {'여행지': ['유럽', '아시아'],
#  '예상경비1일': ['100000', '400000', '300000', '150000'],
#  '예상일정': ['4일갈까?', '~7일도좋아', '20일##']}

# %%
# 미션: 국내,해외여행중 random으로 출력
import random

# result = random.randint(0, 2)
# data['여행'][result]

random_trip = {key:random.choice(values) for key, values in data.items()}
random_trip
# Out:
# {'여행': {'여행지': ['유럽', '아시아'],
#   '예상경비1일': ['100000', '400000', '300000', '150000'],
#   '예상일정': ['4일갈까?', '~7일도좋아', '20일##']}}

# %%
# 최종: 국내,해외여행지 random하게 나오며, 국내, 해외여행지에서 다시 random하게 여행지, 예상경비1일,예상일정을
# 랜덤여행일정에 제작
# 예상경비1일*예상일정이 들어간 최종 경비까지 출력되게함
# 최종출력물=> 랜덤여행일정=[여행지,예상경비1일숫자로,예상일정숫자로, 예상경비1일*예상일정]

def trip(where_to_go):
    # where_to_go = {key:random.choice(values) for key, values in data.items()}
    random_trip = {}

    for key, sub_dict in where_to_go.items():       # sub_dict는 주어진 데이터가 키:값(딕셔너리) 라서..
        # for sub_key, sub_value in sub_dict.items(): # 딕셔너리를 value로 가지니까 또 그안의 딕셔너리에서 서브키, 서브 value 뽑아서..
        #     random_values[sub_key] = random.choice(sub_value)
        random_trip[key] = random.choice(sub_dict)

        # random_trip[key] = random_values
    
    return random_trip

print(trip(data))
type(trip(data))
# Out:
# {'여행': {'여행지': ['유럽', '아시아'], '예상경비1일': ['100000', '400000', '300000', '150000'], '예상일정': ['4일갈까?', '~7일도좋아', '20일##']}}
# dict
