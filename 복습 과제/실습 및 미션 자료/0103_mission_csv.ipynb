# %%
import csv

data = []
f = open('./날씨정보.csv', 'r', encoding='utf-8')
reader = csv.reader(f, delimiter=',')  # \t 탭 키로 들여쓰기 되어 있으면 \t로 ~ 구분 가능

fileName = '날씨정보.csv'

# def myOpen(fileName, 구분자=',')
data = []
f = open('C:/Users/bluecom009/Desktop/AI/복습 과제/실습 및 미션 자료/'+fileName, 'r', encoding='utf-8')
for row in reader:
    data.append(row)
f.close()
    
# return data

fileName = '날씨정보.csv'
# dataList = myOpen(fileName)
data[:3]
# Out:
# [['지점명', '관측시간', '최고기온', '최저기온', '강수량'],
#  ['서울', '2023-01-01', '3.8', '-4.3', ''],
#  ['서울', '2023-01-02', '-0.4', '-7.4', '']]

# %% [markdown]
# #### 헤더를 먼저 분리해야 함
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
# -> ylim은 max값을 찾도록.. 그리고 함수로 쓰는 것이 좋음..
#
# ![image-8.png](attachment:image-8.png)
#
# ![image-7.png](attachment:image-7.png)

# %%
new_num=[]
for x in local:
    if x[4]=='':
        new_num.append(0)
    else:
        new_num.append(float(x[4]))

import matplotlib.pyplot as plt
plt.rcParams['font.family'] ='Malgun Gothic' # 한글깨짐현상때문에 사용
서울,부산,제주=new_num[:30],new_num[31:60],new_num[60:]

plt.figure(figsize=(10,3))
plt.subplot(1,3,1)
plt.plot(서울)
plt.title('서울')
plt.ylim([0,80])

plt.subplot(1,3,2)
plt.plot(부산)
plt.title('부산')
plt.ylim([0,80])

plt.subplot(1,3,3)
plt.plot(제주)
plt.title('제주')
plt.ylim([0,80])
