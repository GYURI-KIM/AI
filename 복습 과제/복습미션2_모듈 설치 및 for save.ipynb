# %% [markdown]
# ### [QR코드 제작 프로그램]
# - QR코드에 대하여 검색하여서 정확한 의미를 정리합니다.
#
#
# - 파이썬에서 QR코드를 제작하는 모듈을 실행해보세요.

# %% [markdown]
# ###  [미션1] QR코드 생성기가 실행될수 있도록 함

# %%
# !pip install qrcode
# Out:
# Collecting qrcode
#   Downloading qrcode-7.4.2-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 kB 610.5 kB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from qrcode) (4.5.0)
# Collecting pypng (from qrcode)
#   Downloading pypng-0.20220715.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 kB 2.5 MB/s eta 0:00:00
# Installing collected packages: pypng, qrcode
# Successfully installed pypng-0.20220715.0 qrcode-7.4.2

# %%
import qrcode

qr_data = 'www.naver.com'
qr_img = qrcode.make(qr_data)

qr_img

# %% [markdown]
# ###  [미션2] qr코드 생성 및 저장
# - QR코드 넣을 폴더를 미리 생성해 놓으세요. (수작업으로해도 됨)
#     -예: c:\\data\\qr

# %%
import os
os.mkdir('c:\data\qr')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-15-1757b15df914> in <cell line: 2>()
#       1 import os
# ----> 2 os.mkdir('c:\data\qr')
#
# FileExistsError: [Errno 17] File exists: 'c:\\data\\qr'

# %% [markdown]
# #### [미션2-1] 이스케이프 문자에 대해 알아봄
# - 폴더지정지 \\를 하는 이유에 대해 알아봄
# - 1번복습자료의 정규표현식에도 나온 내용들임.
#     - 구글검색 '파이썬 이스케이프 문자'

# %%
# 참고: 윈도우즈계열에서는 이스케이프 문자(\)와 디렉토리경로(\)의 혼동을 줄이기 위해
# 디렉토리에서는 \\ 를 사용함.
# 이때 r을 앞에 넣으면 \를 이스케이프문자로 인식하지 않음.
from glob import glob

print(glob("c:\\data\\img\\*\\*"))
print('-------------------------------')
print(glob(r"c:\data\img\*\*"))
# Out:
# []
# -------------------------------
# []

# %% [markdown]
# #### [미션2-2] QR저장
# - 생성된 QR코드를 qr폴더에 저장함. 이때 이름은  qr_data의 www.naver.com 의 naver.png로 저장함
# - qr도 이미지 파일임으로  qr_img.save로 저장가능함.
#     - qr.save(저장경로가있는파일명)

# %%
import qrcode

qr_data = 'www.naver.com'

qr_img = qrcode.make(qr_data)

qr_img

# %%
## [미션2-2-1] www.naver.com에서 naver만 남기고
##         + '.png'  로 문자열을 연결하여 fileName으로 지정함
## fileName은 'naver.png'

###  저장경로 + fileName으로 saveFileName을 제작함
## saveFileName은  'c:\data\qr\naver.png'

baseDir='c:\\data\\qr\\'  # 본인 디렉토리(폴더)로 변경하세요

# %% [markdown]
# ### [미션3] 리스트구조에 있는 사이트를 QR제작하고 저장함
# - 기존에 저장된 파일은 수동으로 모두 제거한뒤 (qr 디렉토리 열어서 삭제) 시작
# - qrList에 있는 사이트의 이름으로 QR제작
#     - naver.png, daum.png, google.png

# %%
qrList=['www.naver.com','www.daum.net','www.google.co.kr']
baseDir='c:\\data\\qr\\'  # 본인디렉토리로 변경하세요.

# %% [markdown]
# ### [미션4] 중복제거하고 QR제작
# - 예를 들어 교육생 선호 검색사이트를 설문조사하거나 크롤링한 자료에서 <br>
# 중복되어 있는 사이트가 나올때, 이를 제거하고 <br>
# QR을 제작하영 봄

# %%
survey=[['홍석현','www.naver.com'],
        ['우병길','www.daum.net'],
        ['조상국','www.daum.com'],
        ['최정기','www.daum.net'],
        ['최순옥','www.daum.net'],
        ['최형기','www.daum.net'],
        ['최건정','www.google.co.kr'],
        ['김정연','www.daum.net'],
        ['김지수','www.google.co.kr'],
        ['김용석','www.daum.net'],
        ['조유승','www.google.co.kr'],
        ['손명준','www.daum.net']
       ]
survey
# Out:
# [['홍석현', 'www.naver.com'],
#  ['우병길', 'www.daum.net'],
#  ['조상국', 'www.daum.com'],
#  ['최정기', 'www.daum.net'],
#  ['최순옥', 'www.daum.net'],
#  ['최형기', 'www.daum.net'],
#  ['최건정', 'www.google.co.kr'],
#  ['김정연', 'www.daum.net'],
#  ['김지수', 'www.google.co.kr'],
#  ['김용석', 'www.daum.net'],
#  ['조유승', 'www.google.co.kr'],
#  ['손명준', 'www.daum.net']]

# %%
# [미션4-1] svrvey의 선호사이트만 출력하여 봄.
# for를 이용해야 한번에 출력할수 있음.
# for가 안될때는 인덱싱해서 한개씩 출력하여 봄

for i in range(0,len(survey)-1):
  print(survey[i])

survey[0]
survey[1]
survey[2]
survey[3]
survey[4]
survey[5]
survey[6]
survey[7]
survey[8]
survey[9]
# Out:
# ['홍석현', 'www.naver.com']
# ['우병길', 'www.daum.net']
# ['조상국', 'www.daum.com']
# ['최정기', 'www.daum.net']
# ['최순옥', 'www.daum.net']
# ['최형기', 'www.daum.net']
# ['최건정', 'www.google.co.kr']
# ['김정연', 'www.daum.net']
# ['김지수', 'www.google.co.kr']
# ['김용석', 'www.daum.net']
# ['조유승', 'www.google.co.kr']
# ['김용석', 'www.daum.net']

# %%
# [미션4-2] site라는 리스트에 survey의 사이트만 추가하고
## 중복제거함( 구글검색 '파이썬 중복 제거')
## 중복제거한 함수는 인덱싱 개념이 없기 때문에 list로 변환해야함.
site=[]
for i in range(0,len(survey)-1):
  site.append(survey[i][1])

siteList=set(site)
siteList.discard('www.daum.com')


print(siteList)

# 최종출력은  site => ['www.google.co.kr', 'www.naver.com', 'www.daum.net']
# Out:
# {'www.naver.com', 'www.google.co.kr', 'www.daum.net'}

# %%
# [미션4-3] 중복제거된 site자료로 qr코드를 제작하고 저장함.
# 위의 미션 4-1,4-2,4-3을 아래에 한번에 작성하세요

# for i in range(0,len(survey)-1):
#   print(survey[i])
import qrcode

site=[]
for i in range(0,len(survey)-1):
  site.append(survey[i][1])

siteList=set(site)
siteList.discard('www.daum.com')


qrList=[]

for qrCode in siteList:
  qr_img=qrcode.make(qrCode)
  print(qr_img)
# Out:
# <qrcode.image.pil.PilImage object at 0x78b56d52f970>
# <qrcode.image.pil.PilImage object at 0x78b56d52fb80>
# <qrcode.image.pil.PilImage object at 0x78b56d52eec0>

# %% [markdown]
# ### [미션5] 자료가 있는 딕셔너리 세트를 이용한 QR제작
# - 외부 json형태로 데이터셋을 받을수 있음으로
# - 딕셔너리 형태의 자료 셋도 필수로 알아야함.

# %%
## [미션5-1] 딕셔너리 구조에서 사이트 주소를 불러와서 QR제작
# 하기 위하여 사이트 주소만 출력하여 봄

qr_data={'사이트주소':['www.daum.net','www.naver.com','www.google.co.kr']}
qrList=[]

for i in qr_data['사이트주소']:
  qrList.append(i)

qrList
# Out:
# ['www.daum.net', 'www.naver.com', 'www.google.co.kr']

# %%
## [미션5-2] 아래의 딕셔너리 구조에서 사이트 주소만 출력하여 봄

qr_data={'data':
         [ {'작성자':'홍석현', '선호사이트':'www.daum.net'},
           {'작성자': '우병길','선호사이트':'www.naver.com'},
          {'작성자': '조상국','선호사이트':'www.google.co.kr'}
        ]
        }

for i in range(0,len(qr_data['data'])):
  print(qr_data['data'][i]['선호사이트'])
# Out:
# www.daum.net
# www.naver.com
# www.google.co.kr

# %% [markdown]
# ### [미션6]  참고: 파일명을 만들기 위한 문자열 제작
#
#
# - 'https://pythontutor.com/'   로 입력한 문자열을 'pythontutor' 로 출력
# - 'http://mqr.kr/generate/email/?hl=ko' 로 입력한 문자열을 'mqr' 만 출력
#
# ==> 문자열 나누기 split를 두번사용해도 되고, 문자열 나누기와 바꾸기 replace를 혼합해서 사용해도됨. <br>
# ==> 프로그램코드를 생각하지 말고 문장구조에서 어떻게 하면 원하는 글자만 남을수 있는지에 대한 규칙을 찾아낼것.

# %%
qr_data1 = 'https://pythontutor.com/'
qrData1=qr_data1.split('https://')
qrData1=qrData1[1].split('.com/')[0]

qrData1=qr_data1.split('https://')[1].replace('pythontutor.com/','pythontutor')
print(qrData1)

qr_data2='http://mqr.kr/generate/email/?hl=ko'
qrData2=qr_data2.split('http://')[1].split('.kr/generate/email/?hl=ko')[0]

print(qrData2)
# Out:
# pythontutor
# mqr
