# %%
a = 1
b = 3
a+b
# Out:
# 4

# %%
print()

# %%
# !pip install PILLOW
# Out:
# ...
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.2/2.6 MB 3.9 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.3/2.6 MB 3.5 MB/s eta 0:00:01
#    ------ --------------------------------- 0.4/2.6 MB 3.2 MB/s eta 0:00:01
#    -------- ------------------------------- 0.5/2.6 MB 3.3 MB/s eta 0:00:01
#    --------- ------------------------------ 0.6/2.6 MB 3.1 MB/s eta 0:00:01
#    ------------ --------------------------- 0.8/2.6 MB 3.0 MB/s eta 0:00:01
#    -------------- ------------------------- 1.0/2.6 MB 3.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.1/2.6 MB 3.2 MB/s eta 0:00:01
#    -------------------- ------------------- 1.4/2.6 MB 3.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.5/2.6 MB 3.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.5/2.6 MB 3.6 MB/s eta 0:00:01
# ...

# %%
# pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/160.4 kB ? eta -:--:--
#      ---------------------------------------- 0.0/160.4 kB ? eta -:--:--
#      ---------------------------------------- 0.0/160.4 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/160.4 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/160.4 kB ? eta -:--:--
#      ------- ----------------------------- 30.7/160.4 kB 262.6 kB/s eta 0:00:01
#      -------------- ---------------------- 61.4/160.4 kB 365.7 kB/s eta 0:00:01
#      -------------- ---------------------- 61.4/160.4 kB 365.7 kB/s eta 0:00:01
#      ------------------------- ---------- 112.6/160.4 kB 437.6 kB/s eta 0:00:01
#      ------------------------------------ 160.4/160.4 kB 534.2 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
# ...

# %%
import PILLOW

# %%
from PIL import Image
Image.open('')
